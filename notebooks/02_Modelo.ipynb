# %% [markdown]
# # **Modelo 1**
#
# - Regressão Logística
# - Hiperparâmetros selecionados
# - Utilização do Min Max Scaler, Standard Scaler e Power Transform para mudanças nas escalas dos dados
# - Pipeline completo
#
# ---

# %% [markdown]
# ### **1. Importações**

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns 
import time

from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split, StratifiedKFold, cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
from sklearn.preprocessing import MinMaxScaler, StandardScaler, PowerTransformer
from sklearn.compose import ColumnTransformer

import joblib

# %%
base = pd.read_csv("../data/train.csv")
teste = pd.read_csv("../data/test.csv")

print(base.shape)
print(teste.shape)
# Out:
# (2000, 21)
# (1000, 21)

# %% [markdown]
# ### **2. Normalizando/padronizando as colunas**

# %% [markdown]
# ```python
# standard_cols = ['battery_power', 'mobile_wt', 'px_height','px_width','ram']
# min_max_cols = ['fc', 'int_memory','pc','sc_h','talk_time']
# sem_preprocessamento = []
#
# for col in xtrain.columns:
#     if col in standard_cols:
#         pass
#     elif col in min_max_cols:
#         pass
#     else:
#         sem_preprocessamento.append(col)
# ```

# %% [markdown]
# ### **3. Criando o modelo de Regressão Logística e o pipeline completo**

# %%
x = base.drop('price_range',axis=1)
y = base.price_range

xtrain, xtest, ytrain, ytest = train_test_split(x,y, test_size=0.1, random_state=0, stratify=y)

# %%
print(ytrain.value_counts())
print(ytest.value_counts())
# Out:
# price_range
# 1    450
# 0    450
# 2    450
# 3    450
# Name: count, dtype: int64
# price_range
# 1    50
# 2    50
# 3    50
# 0    50
# Name: count, dtype: int64

# %%
xtrain.head()
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 1052            547     0          1.9         1   1       0          37
# 1025           1081     1          2.5         1  13       0          49
# 719            1068     0          2.0         1   1       1          37
# 58             1757     0          0.5         0   8       0          49
# 528            1671     0          0.6         1   7       1          61
#
#       m_dep  mobile_wt  n_cores  pc  px_height  px_width   ram  sc_h  sc_w  \
# 1052    0.4        154        5   4        371       541  2705    17     3
# 1025    1.0         99        3  17        284       519   325     9     1
# 719     0.9        184        7  13        186      1998  1803     5     4
# 58      0.5        180        6  14        265       713  2056     7     5
# 528     0.1        129        2  11        263       848  2336    10     4
#
#       talk_time  three_g  touch_screen  wifi
# 1052         10        1             1     0
# 1025          6        0             0     1
# 719           7        1             0     0
# 58            4        0             0     0
# 528           7        1             0     0

# %%
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=0)

scores = []

reg_log = LogisticRegression(
                             solver='lbfgs',
                             penalty='l2',
                             C=1,
                             max_iter=10000,
                             random_state=0)

standard_cols = ['battery_power', 'mobile_wt', 'px_height','px_width','ram']
min_max_cols = ['fc', 'int_memory','pc','sc_h','talk_time']
sem_preprocessamento = []

for col in xtrain.columns:
    if col in standard_cols:
        pass
    elif col in min_max_cols:
        pass
    else:
        sem_preprocessamento.append(col)

preprocessamento = ColumnTransformer(
    transformers=[
        ('std_scaler', StandardScaler(), standard_cols),
        ('minmax_scaler', MinMaxScaler(), min_max_cols),
        ('none', 'passthrough', sem_preprocessamento)  # Passar colunas sem transformação
    ]
)

pipeline = Pipeline(steps=[
    ('preprocessing', preprocessamento),
    ('logreg', reg_log)
])

scores = cross_val_score(pipeline, xtrain, ytrain, cv=skf, scoring='accuracy')


print("Pontuações por fold:", scores)
print("Acurácia média:", round(scores.mean(),4))
# Out:
# Pontuações por fold: [0.96388889 0.96111111 0.96388889 0.96944444 0.95555556]
# Acurácia média: 0.9628

# %%
standard_cols = ['battery_power', 'mobile_wt', 'px_height','px_width','ram']
min_max_cols = ['fc', 'int_memory','pc','sc_h','talk_time']

preprocessamento = ColumnTransformer(
    transformers=[
        ('std_scaler', StandardScaler(), standard_cols),
        ('minmax_scaler', MinMaxScaler(), min_max_cols),
        ('none', 'passthrough', sem_preprocessamento)  # Passar colunas sem transformação
    ]
)

pipeline = Pipeline(steps=[
    ('preprocessing', preprocessamento),
    ('logreg', reg_log)
])

pipeline.fit(xtrain, ytrain)
# Out:
# Pipeline(steps=[('preprocessing',
#                  ColumnTransformer(transformers=[('std_scaler',
#                                                   StandardScaler(),
#                                                   ['battery_power', 'mobile_wt',
#                                                    'px_height', 'px_width',
#                                                    'ram']),
#                                                  ('minmax_scaler',
#                                                   MinMaxScaler(),
#                                                   ['fc', 'int_memory', 'pc',
#                                                    'sc_h', 'talk_time']),
#                                                  ('none', 'passthrough',
#                                                   ['blue', 'clock_speed',
#                                                    'dual_sim', 'four_g',
#                                                    'm_dep', 'n_cores', 'sc_w',
#                                                    'three_g', 'touch_screen',
#                                                    'wifi'])])),
#                 ('logreg',
#                  LogisticRegression(C=1, max_iter=10000, random_state=0))])

# %% [markdown]
# ### **4. Realizando a previsão do xtest e avaliando as métricas**

# %%
previsoes = pipeline.predict(xtest)

metrics.confusion_matrix(ytest, previsoes)
# Out:
# array([[49,  1,  0,  0],
#        [ 2, 46,  2,  0],
#        [ 0,  1, 49,  0],
#        [ 0,  0,  1, 49]])

# %%
print("Acurácia:",metrics.accuracy_score(ytest, previsoes))
print("Precisão:",metrics.precision_score(ytest, previsoes, average='macro'))
print("Recall:",metrics.recall_score(ytest, previsoes, average='macro'))
# Out:
# Acurácia: 0.965
# Precisão: 0.965356334841629
# Recall: 0.965

# %% [markdown]
# - Motivo de utilizar o `average='macro'`:
#
#     - Calcula a métrica para cada classe separadamente e tira a média aritmética (não ponderada) das métricas.
#     - Como funciona: Trata todas as classes igualmente, independentemente do tamanho.
#     - Útil para: Avaliar modelos em cenários onde o desempenho em todas as classes é igualmente importante.

# %% [markdown]
# ### **5. Visualizando as probabilidades do modelo escolher as classes**

# %%
# Visualizando a probabilidade das classes para cada celular

with pd.option_context('display.float_format', '{:.3f}'.format):
    probabilidades = pipeline.predict_proba(teste)
    probabilidades_df = pd.DataFrame(probabilidades)
    display(probabilidades_df.head(20))
# Out:
#        0     1     2     3
# 0  0.000 0.000 0.399 0.601
# 1  0.000 0.000 0.056 0.944
# 2  0.000 0.004 0.620 0.376
# 3  0.000 0.000 0.000 1.000
# 4  0.010 0.873 0.117 0.000
# 5  0.000 0.000 0.052 0.948
# 6  0.000 0.000 0.000 1.000
# 7  0.020 0.953 0.027 0.000
# 8  0.000 0.000 0.103 0.897
# 9  0.992 0.008 0.000 0.000
# 10 0.000 0.000 0.000 1.000
# 11 0.000 0.000 0.001 0.999
# 12 0.985 0.015 0.000 0.000
# 13 0.813 0.187 0.000 0.000
# 14 0.000 0.044 0.901 0.055
# 15 0.828 0.172 0.000 0.000
# 16 0.000 0.043 0.906 0.051
# 17 0.024 0.921 0.055 0.000
# 18 0.000 0.000 0.003 0.997
# 19 0.000 0.362 0.637 0.001

# %% [markdown]
# ### **6. Visualizando os parâmetros do pipeline**

# %%
pipeline.get_params()
# Out:
# {'memory': None,
#  'steps': [('preprocessing',
#    ColumnTransformer(transformers=[('std_scaler', StandardScaler(),
#                                     ['battery_power', 'mobile_wt', 'px_height',
#                                      'px_width', 'ram']),
#                                    ('minmax_scaler', MinMaxScaler(),
#                                     ['fc', 'int_memory', 'pc', 'sc_h',
#                                      'talk_time']),
#                                    ('none', 'passthrough',
#                                     ['blue', 'clock_speed', 'dual_sim', 'four_g',
#                                      'm_dep', 'n_cores', 'sc_w', 'three_g',
#                                      'touch_screen', 'wifi'])])),
#   ('logreg', LogisticRegression(C=1, max_iter=10000, random_state=0))],
#  'transform_input': None,
#  'verbose': False,
#  'preprocessing': ColumnTransformer(transformers=[('std_scaler', StandardScaler(),
#                                   ['battery_power', 'mobile_wt', 'px_height',
#                                    'px_width', 'ram']),
#                                  ('minmax_scaler', MinMaxScaler(),
#                                   ['fc', 'int_memory', 'pc', 'sc_h',
#                                    'talk_time']),
#                                  ('none', 'passthrough',
#                                   ['blue', 'clock_speed', 'dual_sim', 'four_g',
#                                    'm_dep', 'n_cores', 'sc_w', 'three_g',
#                                    'touch_screen', 'wifi'])]),
#  'logreg': LogisticRegression(C=1, max_iter=10000, random_state=0),
#  'preprocessing__force_int_remainder_cols': True,
#  'preprocessing__n_jobs': None,
#  'preprocessing__remainder': 'drop',
#  'preprocessing__sparse_threshold': 0.3,
#  'preprocessing__transformer_weights': None,
#  'preprocessing__transformers': [('std_scaler',
#    StandardScaler(),
#    ['battery_power', 'mobile_wt', 'px_height', 'px_width', 'ram']),
#   ('minmax_scaler',
#    MinMaxScaler(),
#    ['fc', 'int_memory', 'pc', 'sc_h', 'talk_time']),
#   ('none',
#    'passthrough',
#    ['blue',
#     'clock_speed',
#     'dual_sim',
#     'four_g',
#     'm_dep',
#     'n_cores',
#     'sc_w',
#     'three_g',
#     'touch_screen',
#     'wifi'])],
#  'preprocessing__verbose': False,
#  'preprocessing__verbose_feature_names_out': True,
#  'preprocessing__std_scaler': StandardScaler(),
#  'preprocessing__minmax_scaler': MinMaxScaler(),
#  'preprocessing__none': 'passthrough',
#  'preprocessing__std_scaler__copy': True,
#  'preprocessing__std_scaler__with_mean': True,
#  'preprocessing__std_scaler__with_std': True,
#  'preprocessing__minmax_scaler__clip': False,
#  'preprocessing__minmax_scaler__copy': True,
#  'preprocessing__minmax_scaler__feature_range': (0, 1),
#  'logreg__C': 1,
#  'logreg__class_weight': None,
#  'logreg__dual': False,
#  'logreg__fit_intercept': True,
#  'logreg__intercept_scaling': 1,
#  'logreg__l1_ratio': None,
#  'logreg__max_iter': 10000,
#  'logreg__multi_class': 'deprecated',
#  'logreg__n_jobs': None,
#  'logreg__penalty': 'l2',
#  'logreg__random_state': 0,
#  'logreg__solver': 'lbfgs',
#  'logreg__tol': 0.0001,
#  'logreg__verbose': 0,
#  'logreg__warm_start': False}

# %% [markdown]
# ### **7. Aplicando na base de teste (test.csv)**

# %%
teste.head(3)
# Out:
#    id  battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0   1           1043     1          1.8         1  14       0           5
# 1   2            841     1          0.5         1   4       1          61
# 2   3           1807     1          2.8         0   1       0          27
#
#    m_dep  mobile_wt  ...  pc  px_height  px_width   ram  sc_h  sc_w  \
# 0    0.1        193  ...  16        226      1412  3476    12     7
# 1    0.8        191  ...  12        746       857  3895     6     0
# 2    0.9        186  ...   4       1270      1366  2396    17    10
#
#    talk_time  three_g  touch_screen  wifi
# 0          2        0             1     0
# 1          7        1             0     0
# 2         10        0             1     1
#
# [3 rows x 21 columns]

# %%
previsao_base_teste = pipeline.predict(teste.drop("id",axis=1))
previsao_base_teste
# Out:
# array([3, 3, 2, 3, 1, 3, 3, 1, 3, 0, 3, 3, 0, 0, 2, 0, 2, 1, 3, 2, 1, 3,
#        1, 1, 3, 0, 2, 0, 3, 0, 2, 0, 3, 0, 1, 1, 3, 1, 2, 1, 1, 2, 0, 0,
#        0, 1, 0, 3, 1, 2, 1, 0, 3, 0, 3, 0, 3, 1, 1, 3, 3, 3, 0, 1, 1, 1,
#        2, 3, 1, 2, 1, 2, 2, 3, 3, 0, 2, 0, 2, 3, 0, 3, 3, 0, 3, 0, 3, 1,
#        3, 0, 1, 2, 2, 1, 2, 2, 1, 2, 1, 2, 1, 0, 0, 3, 0, 2, 0, 1, 2, 3,
#        3, 3, 1, 3, 3, 3, 3, 2, 3, 0, 0, 3, 2, 1, 2, 0, 3, 2, 2, 2, 0, 2,
#        2, 1, 3, 1, 1, 0, 3, 2, 1, 2, 1, 3, 2, 3, 3, 3, 2, 3, 2, 3, 1, 0,
#        3, 2, 3, 3, 3, 3, 3, 2, 3, 3, 3, 3, 1, 0, 3, 0, 0, 0, 2, 1, 0, 1,
#        0, 0, 1, 2, 1, 0, 0, 1, 1, 2, 2, 1, 0, 0, 0, 1, 0, 3, 1, 0, 2, 2,
#        3, 3, 1, 2, 3, 2, 3, 2, 2, 1, 0, 0, 1, 2, 0, 2, 3, 3, 0, 2, 0, 3,
#        2, 3, 3, 1, 0, 1, 0, 3, 0, 1, 0, 2, 2, 1, 3, 1, 3, 0, 3, 1, 2, 0,
#        0, 2, 1, 3, 3, 3, 1, 1, 3, 0, 0, 2, 3, 3, 1, 3, 1, 1, 3, 2, 1, 2,
#        3, 3, 3, 1, 0, 0, 2, 3, 1, 1, 3, 2, 0, 3, 0, 0, 3, 1, 0, 3, 2, 3,
#        3, 2, 1, 3, 3, 2, 3, 1, 2, 1, 2, 0, 2, 3, 1, 0, 0, 3, 0, 3, 0, 1,
#        2, 0, 2, 3, 1, 3, 2, 2, 1, 2, 0, 0, 0, 1, 3, 2, 0, 0, 0, 3, 2, 0,
#        2, 3, 1, 2, 2, 2, 3, 1, 3, 3, 1, 2, 2, 3, 3, 0, 3, 0, 3, 1, 3, 1,
#        2, 3, 0, 1, 0, 3, 1, 3, 2, 3, 0, 0, 0, 0, 2, 0, 0, 2, 2, 1, 2, 2,
#        2, 0, 1, 0, 0, 3, 2, 0, 3, 1, 2, 2, 1, 2, 3, 1, 1, 2, 2, 1, 2, 0,
#        1, 1, 0, 3, 2, 1, 0, 1, 0, 0, 1, 1, 0, 0, 0, 2, 2, 3, 2, 3, 0, 3,
#        0, 3, 0, 1, 1, 0, 2, 0, 3, 2, 3, 3, 1, 3, 1, 3, 1, 3, 2, 0, 1, 2,
#        1, 1, 0, 0, 0, 1, 2, 1, 0, 3, 2, 0, 2, 2, 0, 0, 3, 1, 2, 0, 2, 3,
#        3, 0, 3, 0, 2, 3, 2, 3, 0, 2, 0, 2, 3, 0, 1, 1, 0, 0, 1, 1, 1, 3,
#        3, 3, 2, 3, 1, 2, 2, 3, 3, 3, 2, 0, 2, 1, 2, 2, 1, 0, 2, 2, 0, 0,
#        0, 3, 1, 0, 2, 2, 2, 0, 3, 1, 2, 2, 1, 3, 0, 2, 3, 0, 1, 1, 3, 3,
#        2, 1, 1, 3, 2, 0, 3, 1, 2, 0, 3, 3, 1, 3, 2, 2, 3, 0, 1, 2, 3, 1,
#        3, 2, 3, 1, 1, 0, 0, 3, 1, 0, 3, 2, 3, 3, 0, 3, 3, 3, 2, 3, 3, 1,
#        2, 0, 2, 2, 3, 1, 0, 1, 1, 2, 2, 2, 0, 0, 2, 2, 3, 2, 0, 2, 1, 3,
#        3, 0, 1, 3, 0, 2, 1, 1, 0, 0, 2, 1, 0, 1, 1, 2, 2, 0, 2, 2, 1, 0,
#        3, 0, 0, 3, 2, 0, 0, 0, 0, 0, 3, 0, 3, 1, 3, 2, 1, 3, 3, 0, 1, 0,
#        3, 2, 2, 2, 0, 3, 0, 2, 0, 2, 0, 0, 1, 1, 1, 2, 1, 3, 1, 3, 2, 2,
#        1, 3, 2, 0, 2, 2, 0, 3, 3, 0, 2, 1, 1, 2, 0, 3, 2, 0, 3, 2, 3, 0,
#        0, 3, 0, 2, 2, 3, 2, 2, 2, 2, 1, 2, 3, 0, 1, 0, 1, 2, 1, 0, 0, 1,
#        0, 0, 3, 0, 1, 2, 0, 1, 1, 1, 3, 0, 3, 2, 3, 0, 0, 1, 2, 2, 1, 0,
#        1, 1, 0, 1, 1, 0, 0, 3, 3, 0, 3, 1, 1, 3, 0, 1, 0, 2, 2, 0, 3, 1,
#        0, 3, 0, 1, 0, 3, 3, 3, 2, 3, 0, 3, 2, 0, 0, 0, 3, 3, 2, 0, 2, 1,
#        3, 0, 0, 2, 2, 0, 3, 1, 2, 1, 1, 1, 3, 1, 1, 1, 2, 1, 0, 2, 2, 0,
#        2, 0, 0, 0, 0, 2, 3, 3, 3, 0, 1, 2, 1, 1, 0, 0, 2, 1, 0, 2, 0, 3,
#        2, 2, 1, 2, 0, 2, 1, 3, 0, 0, 3, 2, 3, 0, 0, 2, 3, 3, 1, 3, 2, 1,
#        0, 0, 3, 3, 1, 3, 0, 0, 0, 2, 2, 1, 2, 0, 3, 2, 1, 2, 3, 3, 0, 1,
#        1, 2, 1, 2, 2, 0, 1, 3, 1, 1, 3, 0, 2, 3, 2, 1, 1, 1, 3, 3, 0, 2,
#        3, 0, 2, 3, 2, 2, 2, 3, 2, 0, 1, 2, 1, 2, 1, 1, 2, 2, 2, 1, 2, 1,
#        0, 1, 3, 1, 0, 1, 2, 3, 1, 0, 0, 3, 2, 2, 3, 0, 3, 2, 2, 1, 3, 0,
#        1, 3, 1, 1, 1, 2, 3, 2, 0, 3, 0, 2, 3, 0, 3, 1, 3, 3, 1, 0, 2, 3,
#        1, 0, 2, 1, 2, 1, 2, 0, 2, 2, 0, 2, 3, 2, 3, 0, 2, 1, 1, 2, 2, 3,
#        3, 0, 2, 1, 2, 1, 3, 1, 1, 3, 0, 1, 0, 0, 3, 3, 2, 0, 0, 0, 0, 3,
#        2, 3, 3, 0, 0, 2, 1, 0, 2, 2])

# %%
df_previsoes = pd.DataFrame({'id':range(1,1001),
                             'price_range':previsao_base_teste})

df_previsoes
# Out:
#        id  price_range
# 0       1            3
# 1       2            3
# 2       3            2
# 3       4            3
# 4       5            1
# ..    ...          ...
# 995   996            2
# 996   997            1
# 997   998            0
# 998   999            2
# 999  1000            2
#
# [1000 rows x 2 columns]

# %%
# Salvando para que possamos comparar os resultados
df_previsoes.to_csv("../data/previsoes_modelo_regressao_logistica.csv", index=False)

# %%
# Exportando o pipeline
joblib.dump(pipeline, '../models/pipeline_modelo_1.joblib')
# Out:
# ['../models/pipeline_modelo_1.joblib']
